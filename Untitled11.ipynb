# %% [markdown]
# ##extracting the data from directories and create test and train generator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test_dir = "/content/drive/MyDrive/tumor_dataset_contrast/test"
train_dir = "/content/drive/MyDrive/tumor_dataset_contrast/train"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

train_datagen = ImageDataGenerator(rescale=1.0/255)

test_datagen = ImageDataGenerator(rescale=1.0/255)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (64,64),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    shuffle=False,
    target_size = (64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1503 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ##builing up the models

# %%
my_model1 = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')  # 3 classes
])

my_model1.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 62, 62, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 29, 29, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │         802,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 841,795 (3.21 MB)
#  Trainable params: 841,795 (3.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
my_model2 = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(3, activation='softmax')  # 3 classes
])

my_model2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 62, 62, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 29, 29, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │         802,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 841,795 (3.21 MB)
#  Trainable params: 841,795 (3.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##training the models

# %%
# Compile the model
my_model1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stopping1 = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
model_checkpoint1 = ModelCheckpoint('my_model1.keras', monitor='val_loss', save_best_only=True, mode="auto", verbose=1)

history3 = my_model1.fit(
    train_generator,
    validation_data=test_generator,
    epochs=15,
    callbacks=[early_stopping1, model_checkpoint1]
)
# Out:
# Epoch 1/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5897 - loss: 0.8394
# Epoch 1: val_loss improved from inf to 0.50651, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 273s 5s/step - accuracy: 0.5907 - loss: 0.8371 - val_accuracy: 0.8033 - val_loss: 0.5065
# Epoch 2/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - accuracy: 0.7399 - loss: 0.5403
# Epoch 2: val_loss improved from 0.50651 to 0.43327, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 90s 794ms/step - accuracy: 0.7401 - loss: 0.5402 - val_accuracy: 0.8167 - val_loss: 0.4333
# Epoch 3/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.8284 - loss: 0.4182
# Epoch 3: val_loss improved from 0.43327 to 0.33555, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 770ms/step - accuracy: 0.8284 - loss: 0.4180 - val_accuracy: 0.8533 - val_loss: 0.3355
# Epoch 4/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.8840 - loss: 0.2944
# Epoch 4: val_loss improved from 0.33555 to 0.26542, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 792ms/step - accuracy: 0.8840 - loss: 0.2942 - val_accuracy: 0.9033 - val_loss: 0.2654
# Epoch 5/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.9161 - loss: 0.2221
# Epoch 5: val_loss improved from 0.26542 to 0.25161, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 822ms/step - accuracy: 0.9160 - loss: 0.2222 - val_accuracy: 0.9067 - val_loss: 0.2516
# Epoch 6/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 600ms/step - accuracy: 0.9334 - loss: 0.1833
# Epoch 6: val_loss improved from 0.25161 to 0.22498, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 776ms/step - accuracy: 0.9336 - loss: 0.1830 - val_accuracy: 0.9033 - val_loss: 0.2250
# Epoch 7/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.9564 - loss: 0.1260
# Epoch 7: val_loss did not improve from 0.22498
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 773ms/step - accuracy: 0.9564 - loss: 0.1260 - val_accuracy: 0.8450 - val_loss: 0.3342
# Epoch 8/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.9655 - loss: 0.1199
# Epoch 8: val_loss did not improve from 0.22498
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 793ms/step - accuracy: 0.9656 - loss: 0.1195 - val_accuracy: 0.9117 - val_loss: 0.2337
# Epoch 9/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.9865 - loss: 0.0520
# Epoch 9: val_loss improved from 0.22498 to 0.16492, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 787ms/step - accuracy: 0.9865 - loss: 0.0521 - val_accuracy: 0.9283 - val_loss: 0.1649
# Epoch 10/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.9932 - loss: 0.0325
# Epoch 10: val_loss did not improve from 0.16492
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 756ms/step - accuracy: 0.9932 - loss: 0.0326 - val_accuracy: 0.9350 - val_loss: 0.1649
# Epoch 11/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.9987 - loss: 0.0184
# Epoch 11: val_loss improved from 0.16492 to 0.16006, saving model to my_model1.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 810ms/step - accuracy: 0.9987 - loss: 0.0184 - val_accuracy: 0.9317 - val_loss: 0.1601
# Epoch 12/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.9990 - loss: 0.0132
# Epoch 12: val_loss did not improve from 0.16006
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 781ms/step - accuracy: 0.9989 - loss: 0.0134 - val_accuracy: 0.9333 - val_loss: 0.1618
# Epoch 13/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 700ms/step - accuracy: 0.9980 - loss: 0.0167
# Epoch 13: val_loss did not improve from 0.16006
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 46s 880ms/step - accuracy: 0.9980 - loss: 0.0167 - val_accuracy: 0.9283 - val_loss: 0.2089
# Epoch 14/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.9999 - loss: 0.0056
# Epoch 14: val_loss did not improve from 0.16006
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 792ms/step - accuracy: 0.9998 - loss: 0.0056 - val_accuracy: 0.9233 - val_loss: 0.2245
# Epoch 15/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.9980 - loss: 0.0088
# Epoch 15: val_loss did not improve from 0.16006
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 800ms/step - accuracy: 0.9981 - loss: 0.0087 - val_accuracy: 0.9383 - val_loss: 0.1909

# %%
import numpy as np
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
import matplotlib.pyplot as plt

predictions = my_model1.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

cm = confusion_matrix(true_classes , predicted_classes)

#plot---
disp = ConfusionMatrixDisplay(confusion_matrix = cm , display_labels = class_labels)
disp.plot(cmap = plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 445ms/step

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history3.history['accuracy'], label='Training Accuracy')
plt.plot(history3.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history3.history['loss'], label='Training Loss')
plt.plot(history3.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Compile the model
my_model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stopping2 = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
model_checkpoint2 = ModelCheckpoint('my_model2.keras', monitor='val_loss', save_best_only=True, mode="auto", verbose=1)

history2 = my_model2.fit(
    train_generator,
    validation_data=test_generator,
    epochs=15,
    callbacks=[early_stopping2, model_checkpoint2]
)
# Out:
# Epoch 1/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.5400 - loss: 0.8899
# Epoch 1: val_loss improved from inf to 0.53229, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 49s 912ms/step - accuracy: 0.5416 - loss: 0.8874 - val_accuracy: 0.7833 - val_loss: 0.5323
# Epoch 2/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.7591 - loss: 0.5692
# Epoch 2: val_loss improved from 0.53229 to 0.43824, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 795ms/step - accuracy: 0.7589 - loss: 0.5692 - val_accuracy: 0.8117 - val_loss: 0.4382
# Epoch 3/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.8066 - loss: 0.4500
# Epoch 3: val_loss improved from 0.43824 to 0.43429, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 832ms/step - accuracy: 0.8065 - loss: 0.4498 - val_accuracy: 0.7700 - val_loss: 0.4343
# Epoch 4/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.8242 - loss: 0.3917
# Epoch 4: val_loss improved from 0.43429 to 0.34502, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 791ms/step - accuracy: 0.8247 - loss: 0.3910 - val_accuracy: 0.8617 - val_loss: 0.3450
# Epoch 5/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.9031 - loss: 0.2620
# Epoch 5: val_loss improved from 0.34502 to 0.26168, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 790ms/step - accuracy: 0.9032 - loss: 0.2617 - val_accuracy: 0.8983 - val_loss: 0.2617
# Epoch 6/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.9301 - loss: 0.1746
# Epoch 6: val_loss improved from 0.26168 to 0.19832, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 794ms/step - accuracy: 0.9302 - loss: 0.1747 - val_accuracy: 0.9233 - val_loss: 0.1983
# Epoch 7/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.9572 - loss: 0.1367
# Epoch 7: val_loss improved from 0.19832 to 0.18042, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 773ms/step - accuracy: 0.9572 - loss: 0.1367 - val_accuracy: 0.9350 - val_loss: 0.1804
# Epoch 8/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.9541 - loss: 0.1292
# Epoch 8: val_loss improved from 0.18042 to 0.17881, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 804ms/step - accuracy: 0.9540 - loss: 0.1295 - val_accuracy: 0.9350 - val_loss: 0.1788
# Epoch 9/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.9796 - loss: 0.0835
# Epoch 9: val_loss improved from 0.17881 to 0.16841, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 781ms/step - accuracy: 0.9796 - loss: 0.0833 - val_accuracy: 0.9350 - val_loss: 0.1684
# Epoch 10/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9858 - loss: 0.0438
# Epoch 10: val_loss did not improve from 0.16841
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 755ms/step - accuracy: 0.9858 - loss: 0.0438 - val_accuracy: 0.9417 - val_loss: 0.1691
# Epoch 11/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9866 - loss: 0.0431
# Epoch 11: val_loss improved from 0.16841 to 0.15265, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 794ms/step - accuracy: 0.9866 - loss: 0.0433 - val_accuracy: 0.9417 - val_loss: 0.1527
# Epoch 12/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - accuracy: 0.9957 - loss: 0.0332
# Epoch 12: val_loss did not improve from 0.15265
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 793ms/step - accuracy: 0.9956 - loss: 0.0332 - val_accuracy: 0.9317 - val_loss: 0.1825
# Epoch 13/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.9964 - loss: 0.0202
# Epoch 13: val_loss improved from 0.15265 to 0.13564, saving model to my_model2.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 780ms/step - accuracy: 0.9963 - loss: 0.0202 - val_accuracy: 0.9500 - val_loss: 0.1356
# Epoch 14/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9887 - loss: 0.0228
# Epoch 14: val_loss did not improve from 0.13564
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 44s 875ms/step - accuracy: 0.9887 - loss: 0.0228 - val_accuracy: 0.9233 - val_loss: 0.2220
# Epoch 15/15
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.9942 - loss: 0.0191
# Epoch 15: val_loss did not improve from 0.13564
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 46s 901ms/step - accuracy: 0.9942 - loss: 0.0191 - val_accuracy: 0.9350 - val_loss: 0.1664

# %%
import numpy as np
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
import matplotlib.pyplot as plt

predictions = my_model2.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

cm = confusion_matrix(true_classes , predicted_classes)

#plot---
disp = ConfusionMatrixDisplay(confusion_matrix = cm , display_labels = class_labels)
disp.plot(cmap = plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 507ms/step

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
